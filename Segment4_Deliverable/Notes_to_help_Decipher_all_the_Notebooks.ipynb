# %% [markdown]
# # Chocolate_Bar_ensemble.ipynb
#
# ### BalancedRandomForestClassifier
#
# **balanced_accuracy_score**
# ```
# 0.606504351917196
# ```
#
# **confusion matrix**
# ```
# array([[416, 238],
#        [ 55,  75]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.88      0.64      0.58      0.74      0.61      0.37       654
#           1       0.24      0.58      0.64      0.34      0.61      0.36       130
#
# avg / total       0.78      0.63      0.59      0.67      0.61      0.37       784
# ```
#
#
#
# ### EasyEnsembleClassifier
#
# **balanced_accuracy_score**
# ```
# 0.5869560103505058
# ```
#
# **confusion matrix**
# ```
# array([[320, 334],
#        [ 41,  89]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.89      0.49      0.68      0.63      0.58      0.33       654
#           1       0.21      0.68      0.49      0.32      0.58      0.34       130
#
# avg / total       0.77      0.52      0.65      0.58      0.58      0.33       784
#
# ```
#
# # Chocolate_Bar_resampling.ipynb
#
#
# ### Logistic Regression with RandomOversampler
#
# **balanced_accuracy_score**
# ```
# 0.5764996471418489
# ```
#
# **confusion_matrix**
# ```
# array([[340, 314],
#        [ 56,  74]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.64      0.52      0.74      0.57      0.33       654
#           1       0.22      0.52      0.64      0.31      0.57      0.32       130
#
# avg / total       0.76      0.62      0.54      0.66      0.57      0.33       784
# ```
#
# ### Logistic Regression with SMOTE Oversampling
# **balanced_accuracy_score**
# ```
# 0.5620677487649964
# ```
#
# **confusion_matrix**
# ```
# array([[378, 276],
#        [ 59,  71]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.58      0.55      0.69      0.56      0.32       654
#           1       0.20      0.55      0.58      0.30      0.56      0.31       130
#
# avg / total       0.76      0.57      0.55      0.63      0.56      0.32       784
# ```
#
# ### Logistic Regression with ClusterCentroids Undersampling
# **balanced_accuracy_score**
# ```
# 0.5693719124911786
# ```
#
# **confusion_matrix**
# ```
# array([[340, 314],
#        [ 56,  74]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.88      0.45      0.68      0.60      0.56      0.30       654
#           1       0.20      0.68      0.45      0.31      0.56      0.32       130
#
# avg / total       0.77      0.49      0.65      0.55      0.56      0.31       784
# ```
#
# ### Logistic Regression with SMOTEEN Combination Oversampling & Undersampling
# **balanced_accuracy_score**
# ```
# 0.5445542225358739
# ```
#
# **confusion_matrix**
# ```
# array([[340, 314],
#        [ 56,  74]], dtype=int64)
# ```
#
# **classification_report_imbalanced**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.52      0.57      0.65      0.54      0.29       654
#           1       0.19      0.57      0.52      0.29      0.54      0.30       130
#
# avg / total       0.75      0.53      0.56      0.59      0.54      0.29       784
# ```

# %% [markdown]
# ### Ingredients Key

# %% [markdown]
# New! Ingredients column ("#" = represents the number of ingredients in the chocolate; B = Beans, S = Sugar, S* = Sweetener other than white cane or beet sugar, C = Cocoa Butter, V = Vanilla, L = Lecithin, Sa = Salt)

# %% [markdown]
# # Data_Clean.ipynb
#
# 1. Add 'Ingredients' and 'Most_Memorable_Characteristics' from webscrape of [flavors_of_cacao](http://flavorsofcacao.com/chocolate_database.html)
# 2. Reformat 'Cocoa_Percent' column
#     + remove '%' char
#     + remove '.' char (decimal point) **BUG (72.5 becomes 725)**
#     + cast string to float
# 3. Fix NA values
#     + Change Ingredients=NA to 'Unknown'
#     + Change Most_Memorable_Characteristics=NA to 'missing'
#     + Call dropna() to catch any other NaN's in df
# 4. If 'Bean_Type' is a list, pick one of Criollo, Trinitario, or Forastero
# 5. Change Unicode 'Non-Breaking Space' char to ASCII string 'missing'
# 6. Fix Country_Location
#     + Fix mispellings ('Eucador' -> 'Ecuador', 'Niacragua' -> 'Nicaragua', etc.)
#     + Expand acronyms ('U.K.' -> 'United Kingdom', etc.)
#     + Change any City entries to their associated Country ('Amsterdam' -> 'Netherlands', etc.)
# 7. Pick one (most prominent or most likely) country where a list is provided
# 8. Create a 'Continent' column derived from 'Broad_Bean_Origin' column
# 9. Clean 'Continent' column
#     + Pick one most prominent when a list is given
# 10. Do the same thing for the 'Broad_Bean_Origin' column
#     + Pick one most prominent when a list is given
# 11. Drop rows where 'Cocoa_Percent' > 100.0 percent (to **fix bug** in #2 above)
# 12. Create geocoding columns and merge
#     + In 'countries' dataframe, use 2-char (ISO 3166-1 alpha-2) values (i.e. 'AD') to match full string (i.e. 'Andorra') in 'Broad_Bean_Origin' column of original dataframe
#     + Add 'country_code' (2-char), 'latitude', 'longitude' columns to original dataframe
# 13. Fix missing / Null values in new geocoding columns
#     + If 'country_code' == 'NA' -> 'ZZ'
#     + If 'latitude' == 'NA' => '0.00'
#     + If 'longitude' == 'NA' => '0.00'

# %% [markdown]
# # EDA.ipynb
#
# ## Many pre-processing steps from Data_Clean.ipynb
#
# #### What is each country share of Cocoa Production?
#
# ![cocoa_production_per_country](../Segment3_Deliverable/junk_images/cocoa_production_per_country.png)
#
# #### Where are the best cocoa beans grown?
#
# ![best_beans_grown](../Segment3_Deliverable/junk_images/best_beans_grown.png)
#
# #### Which countries produce the highest-rated bars?
#
# ![countries_with_best_bars](../Segment3_Deliverable/junk_images/countries_with_best_bars.png)
#
# #### What’s the relationship between cocoa solids percentage and rating?
#
# ![cocoa_percent_vs_rating](../Segment3_Deliverable/junk_images/cocoa_percent_vs_rating.png)
#
# #### Count of Chocolate Bar Ratings
#
# ![ratings_count](../Segment3_Deliverable/junk_images/ratings_count.png)
#
# #### What percent of Cocoa has the highest and most consumer ratings ?
#
# ![ratings_count_by_cocoa_percent](../Segment3_Deliverable/junk_images/ratings_count_by_cocoa_percent.png)
#
# #### What percent of Cocoa has the highest and most consumer ratings ?
#
# ![another_view_of_cocoa_percent_vs_rating](../Segment3_Deliverable/junk_images/another_view_of_cocoa_percent_vs_rating.png)
#
# #### How can you compare the maximum cocoa percentage to the cocoa percentage that is most used in chocolate bars?
#
# ![cocoa_percent_100_tastes_bad](../Segment3_Deliverable/junk_images/cocoa_percent_100_tastes_bad.png)
#
# #### How can you compare the maximum cocoa percentage to the cocoa percentage that is most used in chocolate bars?
#
# ![cocoa_percent_70_tastes_better](../Segment3_Deliverable/junk_images/cocoa_percent_70_tastes_better.png)
#
#
# ## Also many Classification runs
#
# ### RandomForestClassifier
#
# **accuracy_score**
# ```
# 0.944
# ```
#
# ### Support Vector Machine
#
# **accuracy_score**
# ```
# 0.948
# ```
#
# ### Deep Neural Network
#
# **evaluate**
# ```
# 14/14 - 0s - loss: 1.2629 - accuracy: 0.9416
# Loss: 1.2628765106201172, Accuracy: 0.9415730237960815
# ```

# %% [markdown]
# # Machine_Learning
#
# ### Connect to RDS
#
# **location_table_from_db**
# ```
# SELECT * FROM location_table
# ```
#
# **clean_flavors_from_db**
# ```
# SELECT * FROM clean_flavors_table
# ```
#
# **df_chocolate**
# ```
# SELECT clean_flavors_table .*, location_table.country_code,location_table.longitude, location_table.latitude
# FROM clean_flavors_table
# LEFT JOIN location_table
# ON clean_flavors_table.broad_bean_origin_country = location_table.broad_bean_origin_country;
# ```
#
# **one-hot encode**
# ```
# ['company',
#  'review_date',
#  'bean_type',
#  'broad_bean_origin_country',
#  'ingredients',
#  'continent']
#  ```
#
#  **merge un-encoded columns with one-hot encoded columns**
#  **standardscaler**
#
#  ### Logistic Regression with SMOOTEEN Combination Oversampling & Undersampling
#
# **acccuracy_score**
# ```
# 0.8163265306122449
# ```
#
# **confusion_matrix**
# ```
# array([[294,  33],
#        [ 39,  26]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       327
#            1       0.44      0.40      0.42        65
#
#     accuracy                           0.82       392
#    macro avg       0.66      0.65      0.66       392
# weighted avg       0.81      0.82      0.81       392
# ```
#
# ### RandomForestClassifier with SMOTEEN Combination Oversampling & Undersampling
#
# **accuracy_score**
# ```
# 0.7831632653061225
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.88      0.85      0.43      0.87      0.61      0.38       327
#           1       0.37      0.43      0.85      0.40      0.61      0.35        65
#
# avg / total       0.80      0.78      0.50      0.79      0.61      0.38       392
# ```
#
# ### BalancedRandomForestClassifier
#
# **accuracy_score**
# ```
# 0.7134556574923547
# ```
#
# **confusion_matrix**
# ```
# [[205 122]
#  [ 13  52]]
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.94      0.63      0.80      0.75      0.71      0.49       327
#           1       0.30      0.80      0.63      0.44      0.71      0.51        65
#
# avg / total       0.83      0.66      0.77      0.70      0.71      0.50       392
# ```
#
# ### Support Vector Machine
#
# **accuracy_score**
# ```
# 0.8367346938775511
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       327
#            1       0.52      0.18      0.27        65
#
#     accuracy                           0.84       392
#    macro avg       0.69      0.58      0.59       392
# weighted avg       0.80      0.84      0.80       392
# ```
#
# ### GradientBoost
#
# **accuracy_score**
# ```
# 0.8392857142857143
# ```
#
# **confusion_matrix**
# ```
# array([[317,  10],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       327
#            1       0.55      0.18      0.28        65
#
#     accuracy                           0.84       392
#    macro avg       0.70      0.58      0.59       392
# weighted avg       0.81      0.84      0.80       392
# ```
#
# ### Deep Learning Model
#
# ```
# 13/13 - 0s - loss: 2.2749 - accuracy: 0.7704
# Loss: 2.274895429611206, Accuracy: 0.7704081535339355
# ```

# %%
**accuracy_score**
```
```

**confusion_matrix**
```
```

**classification_report**
```
```

# %% [markdown]
# # Machine_Learning_2
#
# ### Connect to RDS
#
# SQL Same as Machine_Learning above
#
# ### Logistic Regression (no resampling)
#
# **accuracy_score**
# ```
# 0.8163265306122449
#
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89       327
#            1       0.44      0.40      0.42        65
#
#     accuracy                           0.82       392
#    macro avg       0.66      0.65      0.66       392
# weighted avg       0.81      0.82      0.81       392
# ```
#
# ### Naive Random Oversampling
#
# **accuracy_score**
# ```
# 0.700846859562456
# ```
#
# **confusion_matrix**
# ```
# array([[237,  90],
#        [ 21,  44]], dtype=int64)
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.92      0.72      0.68      0.81      0.70      0.49       327
#           1       0.33      0.68      0.72      0.44      0.70      0.49        65
#
# avg / total       0.82      0.72      0.68      0.75      0.70      0.49       392
# ```
#
# ### RandomForestClassifier
#
# **accuracy_score**
# ```
# 0.6063043989649495
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
# ```
#
# ### RandomForestClassifier using N_Estimators up to 200
#
# **accuracy_score MAX**
# ```
# 0.837
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.95      0.26      0.91      0.50      0.27       327
#           1       0.52      0.26      0.95      0.35      0.50      0.23        65
#
# avg / total       0.81      0.84      0.38      0.81      0.50      0.26       392
# ```
#
# ### RandomForestClassifier using max_depth up to 32
#
# **accuracy_score MAX**
# ```
# 0.855
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#                   pre       rec       spe        f1       geo       iba       sup
#
#           0       0.86      0.98      0.22      0.92      0.46      0.23       327
#           1       0.70      0.22      0.98      0.33      0.46      0.20        65
#
# avg / total       0.84      0.85      0.34      0.82      0.46      0.22       392
# ```
#
# ### BalancedRandomForestClassifier
# **accuracy_score**
# ```
# 0.7134556574923547
# ```
#
# **confusion_matrix**
# ```
# [[205 122]
#  [ 13  52]]
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.94      0.63      0.80      0.75      0.71      0.49       327
#           1       0.30      0.80      0.63      0.44      0.71      0.51        65
#
# avg / total       0.83      0.66      0.77      0.70      0.71      0.50       392
# ```
#
# ### EasyEnsembleClassifier with AdaBoost
#
# **accuracy_score**
# ```
# 0.7134556574923547
# ```
#
# **confusion_matrix**
# ```
# array([[205, 122],
#        [ 13,  52]], dtype=int64)
# ```
#
# **classification_report**
# ```
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.94      0.63      0.80      0.75      0.71      0.49       327
#           1       0.30      0.80      0.63      0.44      0.71      0.51        65
#
# avg / total       0.83      0.66      0.77      0.70      0.71      0.50       392
# ```
#
# ### Support Vector Machine
#
# **accuracy_score**
# ```
# 0.8367346938775511
# ```
#
# **confusion_matrix**
# ```
# array([[316,  11],
#        [ 53,  12]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       327
#            1       0.52      0.18      0.27        65
#
#     accuracy                           0.84       392
#    macro avg       0.69      0.58      0.59       392
# weighted avg       0.80      0.84      0.80       392
# ```
#
# ### GradientBoostingClassifier
#
# **accuracy_score**
# ```
# 0.8188775510204082
# ```
#
# **confusion_matrix**
# ```
# array([[303,  24],
#        [ 47,  18]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       327
#            1       0.43      0.28      0.34        65
#
#     accuracy                           0.82       392
#    macro avg       0.65      0.60      0.62       392
# weighted avg       0.79      0.82      0.80       392
# ```
#
# ### Deep Learning Model
#
# 13/13 - 0s - loss: 1.6108 - accuracy: 0.7219
# Loss: 1.6108406782150269, Accuracy: 0.7219387888908386

# %% [markdown]
# # Machine_Learning_Multiclass Classifier
#
# ### Connect to RDS
#
# SQL Same as Machine_Learning above
#
# ### ExtraTreesClassifier with SMOTEEN Combination Oversampling & Undersampling
#
# **accuracy_score**
# ```
# ```
#
# **confusion_matrix**
# ```
# array([[138,  19,  44],
#        [253,  65, 135],
#        [ 46,   6,  78]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            1       0.35      0.44      0.39       201
#            2       0.65      0.31      0.42       453
#            3       0.26      0.63      0.37       130
#
#     accuracy                           0.40       784
#    macro avg       0.42      0.46      0.39       784
# weighted avg       0.51      0.40      0.40       784
# ```
#
# ### RandomForestClassifier with SMOTEEN Combination Oversampling & Undersampling
#
# **accuracy_score**
# ```
# 0.407
# ```
#
# **confusion_matrix**
# ```
# array([[138,  19,  44],
#        [253,  65, 135],
#        [ 46,   6,  78]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            1       0.39      0.49      0.43       201
#            2       0.63      0.32      0.42       453
#            3       0.25      0.59      0.35       130
#
#     accuracy                           0.41       784
#    macro avg       0.43      0.47      0.40       784
# weighted avg       0.51      0.41      0.41       784
# ```
#
# ### Support Vector Machine with SMOTEEN Combination Oversampling & Undersampling
#
# **accuracy_score**
# ```
# 0.358
# ```
#
# **confusion_matrix**
# ```
# array([[138,  19,  44],
#        [253,  65, 135],
#        [ 46,   6,  78]], dtype=int64)
# ```
#
# **classification_report**
# ```
#               precision    recall  f1-score   support
#
#            1       0.32      0.69      0.43       201
#            2       0.72      0.14      0.24       453
#            3       0.30      0.60      0.40       130
#
#     accuracy                           0.36       784
#    macro avg       0.45      0.48      0.36       784
# weighted avg       0.55      0.36      0.32       784
# ```
#
# ### Deep Learning Model
#
# 25/25 - 0s - loss: 3.3009 - accuracy: 0.5357
# Loss: 3.300920248031616, Accuracy: 0.5357142686843872

# %% [markdown]
# # Visualization

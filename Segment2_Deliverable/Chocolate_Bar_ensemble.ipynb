# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
file_path = Path('clean_flavors_of_cacao.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#     Company Bean_Origin_or_Bar_Name   REF  Review_Date  Cocoa_Percent  \
# 0  A. Morin             Agua Grande  1876         2016           63.0
# 1  A. Morin                   Kpime  1676         2015           70.0
# 2  A. Morin                  Atsane  1676         2015           70.0
# 3  A. Morin                   Akata  1680         2015           70.0
# 4  A. Morin                  Quilla  1704         2015           70.0
#
#   Company_Location  Rating Bean_Type    Broad_Bean_Origin Ingredients  \
# 0           France    3.75   missing  Sao Tome & Principe  4- B,S,C,L
# 1           France    2.75   missing                 Togo  4- B,S,C,L
# 2           France    3.00   missing                 Togo  4- B,S,C,L
# 3           France    3.50   missing                 Togo  4- B,S,C,L
# 4           France    3.50   missing                 Peru  4- B,S,C,L
#
#    Most_Memorable_Characteristics country_code  latitude  longitude  \
# 0      sweet, chocolatey, vegetal           ST  0.186360   6.613081
# 1       burnt wood, earthy, choco           TG  8.619543   0.824782
# 2           roasty, acidic, nutty           TG  8.619543   0.824782
# 3  mild profile, chocolaty, spice           TG  8.619543   0.824782
# 4    grainy texture, cocoa, sweet           PE -9.189967 -75.015152
#
#        continent
# 0         Africa
# 1         Africa
# 2         Africa
# 3         Africa
# 4  South America

# %%
df= df.drop(columns=["Company","REF","Bean_Origin_or_Bar_Name","Most_Memorable_Characteristics","continent"], axis=1)
df.head()
# Out:
#    Review_Date  Cocoa_Percent Company_Location  Rating Bean_Type  \
# 0         2016           63.0           France    3.75   missing
# 1         2015           70.0           France    2.75   missing
# 2         2015           70.0           France    3.00   missing
# 3         2015           70.0           France    3.50   missing
# 4         2015           70.0           France    3.50   missing
#
#      Broad_Bean_Origin Ingredients country_code  latitude  longitude
# 0  Sao Tome & Principe  4- B,S,C,L           ST  0.186360   6.613081
# 1                 Togo  4- B,S,C,L           TG  8.619543   0.824782
# 2                 Togo  4- B,S,C,L           TG  8.619543   0.824782
# 3                 Togo  4- B,S,C,L           TG  8.619543   0.824782
# 4                 Peru  4- B,S,C,L           PE -9.189967 -75.015152

# %%
def bin_ratings(rating):
    if rating == 5.75: return 1
    if rating == 5.50: return 1
    if rating == 5.25: return 1
    if rating == 5.00: return 1
    
    if rating == 4.75: return 1
    if rating == 4.50: return 1
    if rating == 4.25: return 1
    if rating == 4.00: return 1
    
    if rating == 3.75: return 1
    if rating == 3.50: return 0
    if rating == 3.25: return 0
    if rating == 3.00: return 0

    if rating == 2.75: return 0
    if rating == 2.50: return 0
    if rating == 2.25: return 0
    if rating == 2.00: return 0
    
    if rating == 1.75: return 0
    if rating == 1.50: return 0
    if rating == 1.25: return 0
    if rating == 1.00: return 0
    
    #print( f"error: rating={rating} type={type(rating)}" )
    return "2"

df['Rating'] = df['Rating'].apply(bin_ratings)

# %% [markdown]
# # Split the Data into Training and Testing

# %%
y = df['Rating']
X = df.drop(columns="Rating", axis=1)
X = pd.get_dummies(X)

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# 0    1634
# 1     326
# Name: Rating, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y,test_size= 0.40,train_size=0.60 , random_state=1, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Ensemble Learners

# %% [markdown]
# ## Balanced Random Forest Classifier

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

brfc = BalancedRandomForestClassifier(n_estimators=500, random_state=1)

# train
brfc.fit(X_train_scaled, y_train)
# Out:
# BalancedRandomForestClassifier(n_estimators=500, random_state=1)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = brfc.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5742295930369326

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual high_risk", "Actual low_risk"], columns=["Predicted high_risk", "Predicted low_risk"])
cm_df
# Out:
#                   Predicted high_risk  Predicted low_risk
# Actual high_risk                  409                 245
# Actual low_risk                    62                  68

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.87      0.63      0.52      0.73      0.57      0.33       654
#           1       0.22      0.52      0.63      0.31      0.57      0.32       130
#
# avg / total       0.76      0.61      0.54      0.66      0.57      0.33       784

# %%
# List the features sorted in descending order by feature importance
importances = brfc.feature_importances_ 

features_importance = sorted(zip(brfc.feature_importances_, X.columns), reverse=True)
for feature in features_importance:
    print(f"{feature[1]}: ({feature[0]})")
# Out:
# Cocoa_Percent: (0.14944069123207843)
# Review_Date: (0.13729223735939386)
# latitude: (0.04513114678657135)
# longitude: (0.04342393623849658)
# Company_Location_United States of America: (0.03007874224387692)
# Ingredients_3- B,S,C: (0.029202684272264242)
# Bean_Type_missing: (0.027879840187005227)
# Ingredients_2- B,S: (0.02630557889076599)
# Ingredients_Unknown: (0.023385234831511215)
# Company_Location_Canada: (0.018921211564178305)
# Bean_Type_Trinitario: (0.01790877500448125)
# Bean_Type_Criollo: (0.017048789749097935)
# Ingredients_5- B,S,C,V,L: (0.015624545148830396)
# Company_Location_France: (0.015587885596570445)
# Ingredients_4- B,S,C,L: (0.015438608953695043)
# Ingredients_4- B,S,C,V: (0.012899020300659982)
# Bean_Type_Forastero: (0.01253910636064469)
# Company_Location_Italy: (0.011546665748336871)
# Company_Location_England: (0.011148169518632439)
# Company_Location_Australia: (0.009086449864212188)
# country_code_VE: (0.008289281802133208)
# Broad_Bean_Origin_Venezuela: (0.008071891730714601)
# Company_Location_Switzerland: (0.007857845982900142)
# Company_Location_Germany: (0.0071577379660202394)
# Company_Location_Ecuador: (0.007024265413217771)
# Broad_Bean_Origin_Dominican Republic: (0.006875285436312427)
# Broad_Bean_Origin_Peru: (0.0068539078205131655)
# country_code_PE: (0.006501549182467803)
# country_code_EC: (0.006414449645183613)
# country_code_DO: (0.006412401213009551)
# Broad_Bean_Origin_Ecuador: (0.006393951127593108)
# country_code_MG: (0.006244727862324117)
# Bean_Type_Blend: (0.006040004151826165)
# Company_Location_Brazil: (0.005748154672629933)
# country_code_ZZ: (0.005724470465365998)
# country_code_BR: (0.00554363776226254)
# Broad_Bean_Origin_Madagascar: (0.005403406142520296)
# Company_Location_Hungary: (0.005336463124680499)
# Broad_Bean_Origin_Brazil: (0.0049891619370449865)
# Company_Location_Belgium: (0.004980806854542308)
# Company_Location_Venezuela: (0.004610993660713088)
# Company_Location_Peru: (0.00431216316713636)
# Broad_Bean_Origin_Unknown: (0.004122296110976696)
# country_code_NI: (0.004098734787745925)
# Company_Location_Austria: (0.004064957472678656)
# Company_Location_Madagascar: (0.0040105051841674766)
# Broad_Bean_Origin_Nicaragua: (0.004004447582643931)
# country_code_BO: (0.003928068874728863)
# country_code_GT: (0.0037228187706239172)
# Broad_Bean_Origin_Trinidad Tobago: (0.00347707629586888)
# Broad_Bean_Origin_Ghana: (0.003453922331939409)
# Broad_Bean_Origin_Bolivia: (0.0034043325364899496)
# Company_Location_Spain: (0.003398139771688216)
# country_code_PG: (0.0033539491519694576)
# country_code_TT: (0.003274276248192761)
# Broad_Bean_Origin_Guatemala: (0.0032665204998302616)
# Company_Location_Israel: (0.0032638151692431835)
# Broad_Bean_Origin_Papua New Guinea: (0.0032274312003543163)
# country_code_CR: (0.003128171291321422)
# country_code_BZ: (0.0031175558803556193)
# country_code_CO: (0.0031117082689632813)
# Ingredients_4- B,Sw,C,Sa: (0.002988740847443578)
# country_code_TZ: (0.002968490785058802)
# Broad_Bean_Origin_Colombia: (0.0029561510692348585)
# Company_Location_Scotland: (0.0028366777109387195)
# Broad_Bean_Origin_Other: (0.0028206885777645103)
# Company_Location_Japan: (0.0027962839443425058)
# country_code_GH: (0.0027877268970029415)
# Broad_Bean_Origin_Tanzania: (0.0027845183645480117)
# Broad_Bean_Origin_United States: (0.002644092814134631)
# Broad_Bean_Origin_Costa Rica: (0.0026400625156339356)
# Broad_Bean_Origin_Belize: (0.0026287746156670867)
# Company_Location_Colombia: (0.0026086697744690367)
# country_code_US: (0.0025514901860952412)
# Company_Location_Netherlands: (0.00253500942834511)
# country_code_VN: (0.002443182358567751)
# country_code_JM: (0.0023921406580410605)
# Company_Location_New Zealand: (0.0023480841830419313)
# country_code_MX: (0.0023072250305262903)
# Broad_Bean_Origin_Honduras: (0.0022188336048156922)
# Company_Location_Guatemala: (0.0022124876535375804)
# country_code_GD: (0.0022098175432357777)
# country_code_HN: (0.0021823239368658214)
# Broad_Bean_Origin_Vietnam: (0.0021822392722951446)
# Company_Location_Denmark: (0.0020495354524793755)
# Broad_Bean_Origin_Indonesia: (0.0019699107024406795)
# Ingredients_2- B,Sw: (0.0019678911542552126)
# Broad_Bean_Origin_Mexico: (0.001944255657698455)
# Broad_Bean_Origin_Grenada: (0.0018569485539396123)
# country_code_HT: (0.001849973736513534)
# Broad_Bean_Origin_Jamaica: (0.001767661256036921)
# Company_Location_Argentina: (0.0017503217274509328)
# Bean_Type_Nacional (Arriba): (0.0016729345108664395)
# country_code_ID: (0.001607625041143754)
# country_code_ST: (0.0015842810866073247)
# Broad_Bean_Origin_Haiti: (0.0015253615363159372)
# Broad_Bean_Origin_Sao Tome & Principe: (0.0014552696221571848)
# Company_Location_Lithuania: (0.0013614075378858663)
# Bean_Type_Amazon, ICS: (0.0012994330916967169)
# Broad_Bean_Origin_Vanuatu: (0.0012451809602034992)
# country_code_VU: (0.0011938030261915387)
# Bean_Type_Beniano: (0.001174854552053005)
# Company_Location_Iceland: (0.0010884539407559218)
# Company_Location_Chile: (0.0010818224776475568)
# Company_Location_Dominican Republic: (0.0010800316711409561)
# Bean_Type_Amazon mix: (0.001059362347462155)
# Company_Location_Honduras: (0.0010399003741337854)
# Company_Location_Singapore: (0.0010299163298281384)
# Company_Location_Costa Rica: (0.0009059619377979042)
# Broad_Bean_Origin_Fiji: (0.0009021179411693036)
# Company_Location_Finland: (0.0008845661071832318)
# Broad_Bean_Origin_Republic of Congo: (0.0008175716598859841)
# country_code_CU: (0.0008141584448366518)
# Ingredients_3- B,Sw,C: (0.0007899324567256717)
# Company_Location_Sao Tome: (0.0007896601697159334)
# Broad_Bean_Origin_Cuba: (0.0007790355728452104)
# Ingredients_5-B,S,C,V,Sa: (0.0007688362226388494)
# country_code_LC: (0.0007642592531817975)
# Broad_Bean_Origin_Saint Lucia: (0.00075776899578601)
# Company_Location_Sweden: (0.0007567676855351695)
# country_code_CG: (0.0007057539808575385)
# country_code_FJ: (0.0006760134294929221)
# Company_Location_South Korea: (0.0006667233205214623)
# Company_Location_Ireland: (0.0006618053472214737)
# Company_Location_Puerto Rico: (0.0006214910186153763)
# Ingredients_4- B,Sw,C,V: (0.0005695049397039013)
# Ingredients_4- B,S,C,Sa: (0.0005676588889119757)
# Broad_Bean_Origin_Cote d'Ivorie: (0.0005620500741211898)
# Company_Location_Poland: (0.0005594410529723183)
# Ingredients_3- B,S,L: (0.0005564616521649019)
# country_code_TG: (0.0005178879373395637)
# Company_Location_Vietnam: (0.0005133895256626835)
# Company_Location_Nicaragua: (0.0005112142719942393)
# Ingredients_6-B,S,C,V,L,Sa: (0.00047623548508495006)
# Company_Location_Portugal: (0.0004532113708930635)
# country_code_MY: (0.000444196606095588)
# country_code_PA: (0.0003988920094412769)
# Company_Location_Mexico: (0.0003895213149241328)
# Broad_Bean_Origin_Togo: (0.0003802849913694182)
# country_code_UG: (0.00037208750059773964)
# Broad_Bean_Origin_Panama: (0.00037197728413250605)
# Company_Location_South Africa: (0.0003673414390686605)
# country_code_CI: (0.00036178221294865914)
# Ingredients_4- B,Sw,C,L: (0.0003552745443364542)
# country_code_SV: (0.0003540666613569821)
# Bean_Type_Amazon: (0.000345167064774835)
# Company_Location_St. Lucia: (0.0003334578476220089)
# Broad_Bean_Origin_India: (0.0003321450764836069)
# Broad_Bean_Origin_Malaysia: (0.00033067791543536784)
# Company_Location_Fiji: (0.00032018946755125245)
# country_code_PH: (0.00031269511517229167)
# Broad_Bean_Origin_El Salvador: (0.0003023632761002608)
# Broad_Bean_Origin_Solomon Islands: (0.00029920707629822757)
# Broad_Bean_Origin_Australia: (0.0002977944313814455)
# Ingredients_3- B,S,V: (0.00029464126089587223)
# country_code_AU: (0.00028128776871482294)
# Ingredients_3- B,Sw,Sa: (0.00026276736642302003)
# country_code_SB: (0.00023976779824552114)
# Bean_Type_CCN51: (0.00023831010092300968)
# Broad_Bean_Origin_Sri Lanka: (0.00023352669777677976)
# Broad_Bean_Origin_Samoa: (0.00022000956887153705)
# country_code_SR: (0.00021975189360047938)
# country_code_LR: (0.00021496260452332045)
# Broad_Bean_Origin_Suriname: (0.00021304495102318437)
# Broad_Bean_Origin_Other(DR/Jam/Tri): (0.00021090727169013478)
# Broad_Bean_Origin_Peru(SMartin,Pangoa,nacional): (0.00020804450840185065)
# Broad_Bean_Origin_Philippines: (0.00020284469126142097)
# Broad_Bean_Origin_Uganda: (0.00019216463903084718)
# country_code_LK: (0.000191467564281184)
# country_code_WS: (0.00018413042731404)
# Ingredients_2- B,C: (0.00017935210875119707)
# Company_Location_Suriname: (0.00017433793080869707)
# Bean_Type_EET: (0.00016552076953927248)
# Ingredients_4- B,S,V,L: (0.00015392872329695055)
# Broad_Bean_Origin_Cameroon: (0.00014388077773085347)
# country_code_IN: (0.00014084906709320354)
# Company_Location_Grenada: (0.00013587604265587858)
# country_code_CM: (0.00013050486631763043)
# Broad_Bean_Origin_Gabon: (0.00012751231624895336)
# Broad_Bean_Origin_Myanmar: (0.00012201780036523829)
# Broad_Bean_Origin_Liberia: (0.00012085768612846161)
# Bean_Type_Matina: (0.00011372726280222843)
# country_code_GA: (0.00010593585809958159)
# Ingredients_1- B: (0.00010261049512561338)
# Ingredients_4- B,Sw,V,L: (9.987210343655684e-05)
# country_code_MM: (9.155396089000642e-05)
# Broad_Bean_Origin_Nigeria: (8.316052721847009e-05)
# country_code_PR: (7.69586179597589e-05)
# Company_Location_Philippines: (7.147016738813211e-05)
# country_code_NG: (6.183882047946586e-05)
# Company_Location_Ghana: (5.682411179155826e-05)
# Broad_Bean_Origin_Puerto Rico: (5.563067848883369e-05)
# Company_Location_India: (5.50970957483768e-05)
# country_code_MQ: (0.0)
# Ingredients_5- B,S,C,L,Sa: (0.0)
# Ingredients_3- B,Sw+H108,C: (0.0)
# Company_Location_Wales: (0.0)
# Company_Location_Russia: (0.0)
# Company_Location_Martinique: (0.0)
# Company_Location_Czech Republic: (0.0)
# Company_Location_Bolivia: (0.0)
# Broad_Bean_Origin_Martinique: (0.0)
# Bean_Type_Nacional: (0.0)

# %% [markdown]
# # Easy Ensemble AdaBoost Classifier

# %%
# Train the EasyEnsembleClassifier
from imblearn.ensemble import EasyEnsembleClassifier
eec = EasyEnsembleClassifier(n_estimators=100, random_state=1)
eec.fit(X_train_scaled, y_train)
# Out:
# EasyEnsembleClassifier(n_estimators=100, random_state=1)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_pred = eec.predict(X_test_scaled)
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5885085862150082

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual high_risk", "Actual low_risk"], columns=["Predicted high_risk", "Predicted low_risk"])
cm_df
# Out:
#                   Predicted high_risk  Predicted low_risk
# Actual high_risk                  317                 337
# Actual low_risk                    40                  90

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.89      0.48      0.69      0.63      0.58      0.33       654
#           1       0.21      0.69      0.48      0.32      0.58      0.34       130
#
# avg / total       0.78      0.52      0.66      0.58      0.58      0.33       784
